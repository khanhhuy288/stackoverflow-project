# %% [markdown]
# # EDA

# %%
from pathlib import Path

import pandas as pd
from ydata_profiling import ProfileReport

DATA = Path("data/stack-overflow-developer-survey-2025/survey_results_public_2025.csv")
df = pd.read_csv(DATA, low_memory=False)

profile = ProfileReport(df, title="Stack Overflow Developer Survey 2025 — Public Results")
profile.to_file("so_survey_2025_profile_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 from pathlib import Path
#       2
#       3 import pandas as pd
# ----> 4 from ydata_profiling import ProfileReport
#       5
#       6 DATA = Path("data/stack-overflow-developer-survey-2025/survey_results_public_2025.csv")
#       7 df = pd.read_csv(DATA, low_memory=False)
#
# File ~/repos/stackoverflow-project/.venv/lib/python3.13/site-packages/ydata_profiling/__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# ...
